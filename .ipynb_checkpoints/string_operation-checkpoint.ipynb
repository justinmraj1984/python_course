# %% [markdown]
# ## String Operation

# %%
first_name = "Justin"
last_name = "Michael Raj"

# %%
print(first_name)
print(last_name)
# Out:
# Justin
# Michael Raj

# %%
input_fname = input("Enter First Name: ")
input_lname = input("Enter Last Name: ")
print(f"Full Name is {input_fname} {input_lname}")
# Out:
# Enter First Name:  Justin
# Enter Last Name:  Michael Raj
# Full Name is Justin Michael Raj

# %%
list(input_fname)
# Out:
# ['J', 'u', 's', 't', 'i', 'n']
